# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.array([0, 5])
y = np.array([0, 250])
plt.plot(x,y)

# %%
plt.plot(x,y)
plt.show()

# %%
plt.plot(x,y,'o')

# %%
a = np.arange(10)
b = np.arange(90,100)
plt.plot(a, b, 'o')

# %%
c = np.random.randint(1, 10, 5)
d = np.random.uniform(1, 10, 5)
plt.plot(c, d, 'o')

# %%
plt.plot(d)

# %%
e = np.random.uniform(5, 4, 7)
plt.plot(e, marker='o', linestyle='dotted')

# %%
f = np.random.uniform(234, 233, 300)
plt.plot(f, marker='o', ls=':')

# %%
plt.plot(e, color='y')

# %%
plt.plot(e, c='#9aa291')

# %%
g = np.random.randint(200, 300, 7)
h = np.random.uniform(200, 300, 7)
plt.plot(g, 'o', c='deepskyblue')
plt.plot(h, marker='o', c='hotpink')
plt.grid()

# %%
plt.scatter(g, h)
plt.scatter(c, d)

# %%
i = np.random.randint(0, 100, 30)
j = np.random.randint(0, 100, 30)
k = np.random.randint(0, 100, 30)
l = np.random.randint(0, 100, 30)
plt.scatter(i, j, c='fuchsia')
plt.scatter(k, l, c='gold')

# %%
m = np.array(["Philipines", "Thailand", "Combodia", "Laos", "Myanmar"])
n = np.random.randint(5000, 100001, 5)
plt.bar(m, n)
# Out:
# <BarContainer object of 5 artists>

# %%
plt.barh(m, n)
# Out:
# <BarContainer object of 5 artists>

# %%
plt.barh(m, n, color='#48d1cc', height=0.5)
# Out:
# <BarContainer object of 5 artists>

# %%
o = np.random.randint(0, 100, 5)
plt.pie(o)
# Out:
# ([<matplotlib.patches.Wedge at 0x1b12f0f9ac0>,
# ...
#  [Text(0.9169626164928313, 0.6076014811985081, ''),
#   Text(-0.9440453306010047, 0.5646046526291119, ''),
#   Text(-0.6355512603904326, -0.897816571141418, ''),
#   Text(0.21875131875252823, -1.0780296195114631, ''),
#   Text(1.0482361870782873, -0.33346798361997815, '')])

# %%
platform = ["Facebook", "Twitter", "Instagram", "Vk", "Snapchat"]
plt.pie(o, labels=platform)
# Out:
# ([<matplotlib.patches.Wedge at 0x1b12f14e040>,
# ...
#  [Text(0.9169626164928313, 0.6076014811985081, 'Facebook'),
#   Text(-0.9440453306010047, 0.5646046526291119, 'Twitter'),
#   Text(-0.6355512603904326, -0.897816571141418, 'Instagram'),
#   Text(0.21875131875252823, -1.0780296195114631, 'Vk'),
#   Text(1.0482361870782873, -0.33346798361997815, 'Snapchat')])

# %%
differ = [.3, 0, 0, 0, 0]
plt.pie(o, labels=platform, explode=differ)
# Out:
# ([<matplotlib.patches.Wedge at 0x1b12edf7fa0>,
# ...
#  [Text(1.1670433300817853, 0.7733109760708284, 'Facebook'),
#   Text(-0.9440453306010047, 0.5646046526291119, 'Twitter'),
#   Text(-0.6355512603904326, -0.897816571141418, 'Instagram'),
#   Text(0.21875131875252823, -1.0780296195114631, 'Vk'),
#   Text(1.0482361870782873, -0.33346798361997815, 'Snapchat')])
